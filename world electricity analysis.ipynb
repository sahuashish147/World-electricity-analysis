# %% [markdown]
# ## Import and export of json file to csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rural_access = pd.read_json("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/world_bank_electricity_report/access_to_elec_rural__world/API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.json")
rural_access.drop(0, inplace =True)
list1 = rural_access.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
rural_access.columns = new_lst
rural_access.drop(1, inplace = True)
rural_access.dropna(axis =1, thresh = 1, inplace = True)
rural_access.drop_duplicates(inplace = True)
rural_access.drop("y_", axis =1, inplace = True)
rural_access.replace("",np.nan, inplace = True)
rural_access.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/rural_access.csv",index = False)
rural_access.head()
# Out:
#                 y_Country Name y_Country Code  \
# 2                        Aruba            ABW
# 3  Africa Eastern and Southern            AFE
# 4                  Afghanistan            AFG
# 5   Africa Western and Central            AFW
# 6                       Angola            AGO
#
#                                     y_Indicator Name   y_Indicator Code  \
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 6  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#   y_1990            y_1991            y_1992            y_1993  \
# 2    100  98.3737741616736  98.4282597493425  98.5017492013514
# 3    NaN               NaN               NaN               NaN
# ...

# %%
last = list(rural_access.columns[15:])
col = [rural_access.columns[1]] 
col.extend(last)
rural_access[col].to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/rural-2000-2020.csv",index = False)

# %%
total = pd.read_json(r"C:\Users\batman\Desktop\my territory\Projects\complete data analysis\world_bank_electricity_report\access_to_electricity__total\API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_4353549.json")
total.drop(0, inplace =True)
list1 = total.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
total.columns = new_lst
total.drop(1, inplace = True)
total.dropna(axis =1, thresh = 1, inplace = True)
total.drop_duplicates(inplace = True)
total.drop("y_", axis =1, inplace = True)
total.replace("",np.nan, inplace = True)
total.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/Total.csv",index = False)
total.head()
# Out:
#                 y_Country Name y_Country Code  \
# 2                        Aruba            ABW
# 3  Africa Eastern and Southern            AFE
# 4                  Afghanistan            AFG
# 5   Africa Western and Central            AFW
# 6                       Angola            AGO
#
#                           y_Indicator Name y_Indicator Code y_1990  \
# 2  Access to electricity (% of population)   EG.ELC.ACCS.ZS    100
# 3  Access to electricity (% of population)   EG.ELC.ACCS.ZS    NaN
# 4  Access to electricity (% of population)   EG.ELC.ACCS.ZS    NaN
# 5  Access to electricity (% of population)   EG.ELC.ACCS.ZS    NaN
# 6  Access to electricity (% of population)   EG.ELC.ACCS.ZS    NaN
#
#              y_1991            y_1992            y_1993            y_1994  \
# 2  99.1536560058594  99.1971282958984  99.2399139404297               100
# 3               NaN               NaN               NaN               NaN
# ...

# %%
last = list(total.columns[15:])
col = [total.columns[1]] 
col.extend(last)
total[col].to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/total-2000-2020.csv",index = False)

# %%
urban_access = pd.read_json(r"C:\Users\batman\Desktop\my territory\Projects\complete data analysis\world_bank_electricity_report\access_to_electricity_urban__world\API_EG.ELC.ACCS.UR.ZS_DS2_en_csv_v2_4367536.json")
urban_access.drop(0, inplace =True)
list1 = urban_access.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
urban_access.columns = new_lst
urban_access.drop(1, inplace = True)
urban_access.dropna(axis =1, thresh = 1, inplace = True)
urban_access.drop_duplicates(inplace = True)
urban_access.drop("y_", axis =1, inplace = True)
urban_access.replace("",np.nan, inplace = True)
urban_access.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/Urban.csv",index = False)
urban_access.head()
# Out:
#                 y_Country Name y_Country Code  \
# 2                        Aruba            ABW
# 3  Africa Eastern and Southern            AFE
# 4                  Afghanistan            AFG
# 5   Africa Western and Central            AFW
# 6                       Angola            AGO
#
#                                     y_Indicator Name   y_Indicator Code  \
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 6  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#   y_1990            y_1991           y_1992            y_1993  \
# 2    100  99.9241333007813  99.966064453125  99.9903564453125
# 3    NaN               NaN              NaN               NaN
# ...

# %%
last = list(urban_access.columns[15:])
col = [urban_access.columns[1]] 
col.extend(last)
urban_access[col].to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/urban-2000-2020.csv",index = False)

# %%
loss = pd.read_json(r"C:\Users\batman\Desktop\my territory\Projects\complete data analysis\world_bank_electricity_report\electricity_power_transmissoin_distribution_losses\API_EG.ELC.LOSS.ZS_DS2_en_csv_v2_4357259.json")
loss.drop(0, inplace =True)
list1 = loss.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
loss.columns = new_lst
loss.drop(1, inplace = True)
loss.dropna(axis =1, thresh = 1, inplace = True)
loss.drop_duplicates(inplace = True)
loss.drop("y_", axis =1, inplace = True)
loss.replace("",np.nan, inplace = True)
loss.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/Power_loss.csv",index = False)
loss.head()
# Out:
#                 y_Country Name y_Country Code  \
# 2                        Aruba            ABW
# 3  Africa Eastern and Southern            AFE
# 4                  Afghanistan            AFG
# 5   Africa Western and Central            AFW
# 6                       Angola            AGO
#
#                                     y_Indicator Name y_Indicator Code y_1960  \
# 2  Electric power transmission and distribution l...   EG.ELC.LOSS.ZS    NaN
# 3  Electric power transmission and distribution l...   EG.ELC.LOSS.ZS    NaN
# 4  Electric power transmission and distribution l...   EG.ELC.LOSS.ZS    NaN
# 5  Electric power transmission and distribution l...   EG.ELC.LOSS.ZS    NaN
# 6  Electric power transmission and distribution l...   EG.ELC.LOSS.ZS    NaN
#
#   y_1961 y_1962 y_1963 y_1964 y_1965  ...            y_2005            y_2006  \
# 2    NaN    NaN    NaN    NaN    NaN  ...               NaN               NaN
# ...

# %%
nuclear = pd.read_json(r"C:\Users\batman\Desktop\my territory\Projects\complete data analysis\world_bank_electricity_report\electricity_production_nuclear_sources\API_EG.ELC.NUCL.ZS_DS2_en_csv_v2_4357319.json")
nuclear.drop(0, inplace =True)
list1 = nuclear.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
nuclear.columns = new_lst
nuclear.drop(1, inplace = True)
nuclear.dropna(axis =1, thresh = 1, inplace = True)
nuclear.drop_duplicates(inplace = True)
nuclear.drop("y_", axis =1, inplace = True)
nuclear.replace("",np.nan, inplace = True)
nuclear.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/nuclear.csv",index = False)
nuclear.head()
# Out:
#                 y_Country Name y_Country Code  \
# 2                        Aruba            ABW
# 3  Africa Eastern and Southern            AFE
# 4                  Afghanistan            AFG
# 5   Africa Western and Central            AFW
# 6                       Angola            AGO
#
#                                     y_Indicator Name y_Indicator Code y_1960  \
# 2  Electricity production from nuclear sources (%...   EG.ELC.NUCL.ZS    NaN
# 3  Electricity production from nuclear sources (%...   EG.ELC.NUCL.ZS    NaN
# 4  Electricity production from nuclear sources (%...   EG.ELC.NUCL.ZS    NaN
# 5  Electricity production from nuclear sources (%...   EG.ELC.NUCL.ZS    NaN
# 6  Electricity production from nuclear sources (%...   EG.ELC.NUCL.ZS    NaN
#
#   y_1961 y_1962 y_1963 y_1964 y_1965  ...            y_2006            y_2007  \
# 2    NaN    NaN    NaN    NaN    NaN  ...               NaN               NaN
# ...

# %%
oil = pd.read_json(r"C:\Users\batman\Desktop\my territory\Projects\complete data analysis\world_bank_electricity_report\electricity_production_oil_sources\API_EG.ELC.PETR.ZS_DS2_en_csv_v2_4356435.json")
oil.drop(0, inplace =True)
list1 = oil.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
oil.columns = new_lst
oil.drop(1, inplace = True)
oil.dropna(axis =1, thresh = 1, inplace = True)
oil.drop_duplicates(inplace = True)
oil.drop("y_", axis =1, inplace = True)
oil.replace("",np.nan, inplace = True)
oil.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/oil.csv",index = False)

# %%
renewable = pd.read_json(r"C:\Users\batman\Desktop\my territory\Projects\complete data analysis\world_bank_electricity_report\electricity_production_renewable_sources\API_EG.ELC.RNWX.KH_DS2_en_csv_v2_4356007.json")
renewable.drop(0, inplace =True)
list1 = renewable.iloc[0,:].to_list()
new_lst = []
for i in list1:
    new_lst.append("y_"+str(i))
renewable.columns = new_lst
renewable.drop(1, inplace = True)
renewable.dropna(axis =1, thresh = 1, inplace = True)
renewable.drop_duplicates(inplace = True)
renewable.drop("y_", axis =1, inplace = True)
renewable.replace("",np.nan, inplace = True)
renewable.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/renewable.csv",index = False, header = True)
renewable.head()
# Out:
#                 y_Country Name y_Country Code  \
# 2                        Aruba            ABW
# 3  Africa Eastern and Southern            AFE
# 4                  Afghanistan            AFG
# 5   Africa Western and Central            AFW
# 6                       Angola            AGO
#
#                                     y_Indicator Name y_Indicator Code  \
# 2  Electricity production from renewable sources,...   EG.ELC.RNWX.KH
# 3  Electricity production from renewable sources,...   EG.ELC.RNWX.KH
# 4  Electricity production from renewable sources,...   EG.ELC.RNWX.KH
# 5  Electricity production from renewable sources,...   EG.ELC.RNWX.KH
# 6  Electricity production from renewable sources,...   EG.ELC.RNWX.KH
#
#    y_1960.0  y_1961.0  y_1962.0  y_1963.0  y_1964.0  y_1965.0  ...  \
# 2       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 3       NaN       NaN       NaN       NaN       NaN       NaN  ...
# ...

# %%
null = rural_access.isnull().sum()[4:]
null
# Out:
# y_1990    166
# y_1991    155
# y_1992    140
# y_1993    126
# y_1994    119
# y_1995    111
# y_1996    101
# y_1997     99
# y_1998     93
# y_1999     87
# y_2000     28
# y_2001     28
# y_2002     28
# y_2003     19
# y_2004     15
# y_2005     17
# y_2006     15
# y_2007     15
# y_2008     14
# y_2009     16
# y_2010     14
# y_2011     13
# y_2012     13
# y_2013     11
# y_2014      9
# y_2015      7
# y_2016     11
# y_2017     15
# y_2018     16
# y_2019     15
# y_2020      9
# dtype: int64

# %%
null = rural_access.isnull().sum()[4:]
plt.subplots(figsize=(17,9.5))
sns.barplot( x= null.values, y = null.index, palette = 'cool')
# Out:
# <AxesSubplot:>

# %%
all_three = pd.concat([rural_access,total,urban_access])
last = list(all_three.columns[14:])
col = list(all_three.columns[:4])
col.extend(last)

# %%
all_three[col].to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/2000-2020.csv",index = False)

# %%
all_three[col].isnull().sum()
# Out:
# y_Country Name       0
# y_Country Code       0
# y_Indicator Name     0
# y_Indicator Code     0
# y_2000              42
# y_2001              42
# y_2002              41
# y_2003              32
# y_2004              28
# y_2005              30
# y_2006              27
# y_2007              25
# y_2008              24
# y_2009              24
# y_2010              21
# y_2011              21
# y_2012              19
# y_2013              17
# y_2014              15
# y_2015              13
# y_2016              17
# y_2017              25
# y_2018              32
# y_2019              28
# y_2020              17
# dtype: int64

# %% [markdown]
# ## connection with SQL

# %% [markdown]
# ### Q1. Comparison of access to electricity post 2000s in different countries

# %%
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
               'Server=PREDATOR\SQLSERVER;'
               'Database=Project1;'
               'Trusted_Connection=no;')
df = pd.read_sql("  select y_country_name, avg(electricity) as average_usage from (select y_country_name, electricity  from total unpivot (electricity for years in (y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) as N) as M group by y_country_name", conn)
df.head()
# Out:
#                 y_country_name  average_usage
# 0                  Afghanistan      52.520487
# 1  Africa Eastern and Southern      30.145871
# 2   Africa Western and Central      43.447839
# 3                      Albania      99.981429
# 4                      Algeria      99.108147

# %%
all_three = pd.concat([rural_access,total,urban_access])
last = list(all_three.columns[15:])
col = list(all_three.columns[:5])
col.extend(last)
all_three[col].to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/exported from python/2000-2020.csv")

# %% [markdown]
# ## Q3. every country’s performance with respect to world average for every year. (Total)

# %%
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
               'Server=PREDATOR\SQLSERVER;'
               'Database=Project1;'
               'Trusted_Connection=no;')

# %%
df = pd.read_sql("select y_country_name, y_1990, y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020 from (select A.*, B.region, B.incomegroup, B.specialnotes from Total as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.region is not Null or A.y_country_name like '%World%') as N", conn)
df.head()
# Out:
#   y_country_name  y_1990      y_1991      y_1992      y_1993  y_1994  y_1995  \
# 0          Aruba   100.0   99.153656   99.197128   99.239914   100.0   100.0
# 1    Afghanistan     NaN         NaN         NaN         NaN     NaN     NaN
# 2         Angola     NaN         NaN         NaN         NaN     NaN     NaN
# 3        Albania   100.0  100.000000  100.000000  100.000000   100.0   100.0
# 4        Andorra   100.0  100.000000  100.000000  100.000000   100.0   100.0
#
#    y_1996  y_1997  y_1998  ...      y_2011      y_2012      y_2013  \
# 0   100.0   100.0   100.0  ...  100.000000  100.000000  100.000000
# 1     NaN     NaN     NaN  ...   43.222019   69.099998   68.290649
# 2     NaN     NaN     NaN  ...   34.599998   37.131321   38.278030
# 3   100.0   100.0   100.0  ...  100.000000   99.900002  100.000000
# 4   100.0   100.0   100.0  ...  100.000000  100.000000  100.000000
#
#        y_2014      y_2015      y_2016      y_2017      y_2018      y_2019  \
# ...

# %%
last = list(df.columns[11:])
col = [df.columns[0]]
col.extend(last)
df[col]
# Out:
#     y_country_name      y_2000      y_2001      y_2002      y_2003  \
# 0            Aruba   91.660400  100.000000  100.000000  100.000000
# 1      Afghanistan    1.613591    4.074574    9.409158   14.738506
# 2           Angola   24.212744   20.000000   26.352118   27.412777
# 3          Albania  100.000000  100.000000  100.000000  100.000000
# 4          Andorra  100.000000  100.000000  100.000000  100.000000
# ..             ...         ...         ...         ...         ...
# 214         Kosovo         NaN         NaN         NaN         NaN
# 215    Yemen, Rep.   49.187256   50.341240   51.487637   52.628803
# 216   South Africa   72.282463   70.199997   76.699997   78.800003
# 217         Zambia   16.700001   20.172386   17.400000   18.500000
# 218       Zimbabwe   33.654888   34.172844   34.200001   35.188351
#
#          y_2004      y_2005      y_2006      y_2007      y_2008  ...  \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  ...
# ...

# %% [markdown]
# Null value is low after year 2000, we can replace with the help of KNN imputers

# %%
last = list(df.columns[11:])
col = [df.columns[0]]
col.extend(last)
df = df[col]
x = df[df.columns[1:]]
new_list = []
for i in range(df.shape[0]):
    i *= 100000
    new_list.append(i)
x['new_column'] = new_list
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors = 2)
y = knn.fit_transform(x)
df[df.columns[1:]]  = y[:,:-1]

# %%
df
# Out:
#     y_country_name      y_2000      y_2001      y_2002      y_2003  \
# 0            Aruba   91.660400  100.000000  100.000000  100.000000
# 1      Afghanistan    1.613591    4.074574    9.409158   14.738506
# 2           Angola   24.212744   20.000000   26.352118   27.412777
# 3          Albania  100.000000  100.000000  100.000000  100.000000
# 4          Andorra  100.000000  100.000000  100.000000  100.000000
# ..             ...         ...         ...         ...         ...
# 214         Kosovo   68.522541   69.462944   70.395758   71.323343
# 215    Yemen, Rep.   49.187256   50.341240   51.487637   52.628803
# 216   South Africa   72.282463   70.199997   76.699997   78.800003
# 217         Zambia   16.700001   20.172386   17.400000   18.500000
# 218       Zimbabwe   33.654888   34.172844   34.200001   35.188351
#
#          y_2004      y_2005      y_2006      y_2007      y_2008  ...  \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  ...
# ...

# %%
df.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/q3_total.csv", index = False)

# %%
df = pd.read_sql("select y_country_name, y_1990, y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020 from (select A.*, B.region, B.incomegroup, B.specialnotes from urban as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.region is not Null or A.y_country_name like '%World%') as N", conn)
last = list(df.columns[11:])
col = [df.columns[0]]
col.extend(last)
df = df[col]
x = df[df.columns[1:]]
new_list = []
for i in range(df.shape[0]):
    i *= 100000
    new_list.append(i)
x['new_column'] = new_list
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors = 2)
y = knn.fit_transform(x)
df[df.columns[1:]]  = y[:,:-1]
df.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/q3_urban.csv", index = False)
df.head()
# Out:
#   y_country_name      y_2000      y_2001      y_2002      y_2003      y_2004  \
# 0          Aruba  100.000000  100.000000  100.000000  100.000000  100.000000
# 1    Afghanistan   72.133469   73.599037   75.063278   76.533134   78.015556
# 2         Angola   44.817604   30.000000   47.584629   48.973099   50.374130
# 3        Albania  100.000000  100.000000  100.000000  100.000000  100.000000
# 4        Andorra  100.000000  100.000000  100.000000  100.000000  100.000000
#
#       y_2005      y_2006      y_2007      y_2008  ...     y_2011      y_2012  \
# 0  100.00000  100.000000  100.000000  100.000000  ...  100.00000  100.000000
# 1   74.00000   81.043770   82.590820   89.900002  ...   86.56778   95.000000
# 2   51.79467   53.239563   66.099998   61.310001  ...   82.50000   70.463470
# 3  100.00000  100.000000  100.000000  100.000000  ...  100.00000   99.900002
# 4  100.00000  100.000000  100.000000  100.000000  ...  100.00000  100.000000
#
# ...

# %%
df = pd.read_sql("select y_country_name, y_1990, y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020 from (select A.*, B.region, B.incomegroup, B.specialnotes from rural_access as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.region is not Null or A.y_country_name like '%World%') as N", conn)
last = list(df.columns[11:])
col = [df.columns[0]]
col.extend(last)
df = df[col]
x = df[df.columns[1:]]
new_list = []
for i in range(df.shape[0]):
    i *= 100000
    new_list.append(i)
x['new_column'] = new_list
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors = 2)
y = knn.fit_transform(x)
df[df.columns[1:]]  = y[:,:-1]
df.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/q3_rural.csv", index = False)
df.head()
# Out:
#   y_country_name      y_2000      y_2001      y_2002      y_2003      y_2004  \
# 0          Aruba  100.000000  100.000000  100.000000  100.000000  100.000000
# 1    Afghanistan   51.768026   54.738538   51.460638   51.230891    3.240604
# 2         Angola    3.536051    9.477077    2.921275    2.461782    1.885921
# 3        Albania  100.000000  100.000000  100.000000  100.000000  100.000000
# 4        Andorra  100.000000  100.000000  100.000000  100.000000  100.000000
#
#        y_2005      y_2006      y_2007      y_2008  ...     y_2011      y_2012  \
# 0  100.000000  100.000000  100.000000  100.000000  ...  100.00000  100.000000
# 1   11.113852   15.765366   22.060678   27.954250  ...   29.57288   60.849155
# 2    1.188117    0.846493   61.030339    6.609388  ...   64.78644   80.424578
# 3  100.000000  100.000000  100.000000  100.000000  ...  100.00000  100.000000
# 4  100.000000  100.000000  100.000000  100.000000  ...  100.00000  100.000000
#
# ...

# %% [markdown]
# ## Q1. Comparison of access to electricity post 2000s in different countries
# ### rural, urban & total with avg % of popoulation use electricity

# %%
df_r = pd.read_sql(" select y_country_name, avg(electricity) as rural_average_usage from (select y_country_name, electricity  from rural_access unpivot (electricity for years in (y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) as N) as M group by y_country_name", conn)
df_r.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_rural.csv", index = False)
df_r.head()
# Out:
#                 y_country_name  rural_average_usage
# 0                  Afghanistan            54.769483
# 1  Africa Eastern and Southern            17.520759
# 2   Africa Western and Central            20.124076
# 3                      Albania           100.000000
# 4                      Algeria            98.099553

# %%
df_u = pd.read_sql(" select y_country_name, avg(electricity) as urban_average_usage from (select y_country_name, electricity  from urban unpivot (electricity for years in (y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) as N) as M group by y_country_name", conn)
df_u.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_urban.csv", index = False)
df_u.head()
# Out:
#                 y_country_name  urban_average_usage
# 0                  Afghanistan            87.336019
# 1  Africa Eastern and Southern            63.301987
# 2   Africa Western and Central            76.232755
# 3                      Albania            99.995238
# 4                      Algeria            99.595801

# %%
df_t = pd.read_sql(" select y_country_name, avg(electricity) as total_average_usage from (select y_country_name, electricity  from total unpivot (electricity for years in (y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) as N) as M group by y_country_name", conn)
df_t.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_total.csv", index = False)
df_t.head()
# Out:
#                 y_country_name  total_average_usage
# 0                  Afghanistan            52.520487
# 1  Africa Eastern and Southern            30.145871
# 2   Africa Western and Central            43.447839
# 3                      Albania            99.981429
# 4                      Algeria            99.108147

# %%
avg_of_all = pd.concat([df_t.set_index('y_country_name'), df_u.set_index('y_country_name'), df_r.set_index('y_country_name')], axis = 1)
avg_of_all.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_all.csv")
avg_of_all.head()
# Out:
#                              total_average_usage  urban_average_usage  \
# y_country_name
# Afghanistan                            52.520487            87.336019
# Africa Eastern and Southern            30.145871            63.301987
# Africa Western and Central             43.447839            76.232755
# Albania                                99.981429            99.995238
# Algeria                                99.108147            99.595801
#
#                              rural_average_usage
# y_country_name
# Afghanistan                            54.769483
# Africa Eastern and Southern            17.520759
# Africa Western and Central             20.124076
# Albania                               100.000000
# Algeria                                98.099553

# %% [markdown]
# ### income wise electricity consumers
# #### total, rural & urban

# %%
df_t = pd.read_sql("select incomegroup, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002, avg(y_2003) as y_2003, avg(y_2004) as y_2004,  avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007, avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012, avg(y_2013) as y_2013, avg(y_2014) as y_2014, avg(y_2015) as y_2015, avg(y_2016) as y_2016, avg(y_2017) as y_2017, avg(y_2018) as y_2018, avg(y_2019) as y_2019, avg(y_2020) as y_2020 from (select A.*, B.incomegroup from Total as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by incomegroup order by avg(y_2000) Desc", conn)
df_t.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_total_incomewise.csv", index = False)
df_t.head()
# Out:
#            incomegroup     y_2000     y_2001     y_2002     y_2003     y_2004  \
# 0          High income  99.243466  99.385191  99.482007  99.542252  99.491033
# 1  Upper middle income  88.751303  89.340055  89.845001  90.192882  90.518196
# 2  Lower middle income  54.272967  55.094414  56.448380  57.760366  59.155234
# 3           Low income  15.945272  16.808557  16.869524  18.295769  19.521214
#
#       y_2005     y_2006     y_2007     y_2008  ...     y_2011     y_2012  \
# 0  99.442993  99.652709  99.630419  99.647147  ...  99.725971  99.736573
# 1  90.919900  91.509862  91.793307  92.259877  ...  93.599229  94.173549
# 2  60.380818  62.047876  62.988352  64.681190  ...  68.476525  70.072894
# 3  19.596886  20.917225  21.255889  21.546799  ...  25.999896  27.846841
#
#       y_2013     y_2014     y_2015     y_2016     y_2017     y_2018  \
# 0  99.807514  99.870144  99.883989  99.894721  99.912500  99.933209
# 1  94.427960  94.638244  95.031837  95.255319  95.586985  95.694755
# ...

# %%
df_u = pd.read_sql("select incomegroup, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002, avg(y_2003) as y_2003, avg(y_2004) as y_2004,  avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007, avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012, avg(y_2013) as y_2013, avg(y_2014) as y_2014, avg(y_2015) as y_2015, avg(y_2016) as y_2016, avg(y_2017) as y_2017, avg(y_2018) as y_2018, avg(y_2019) as y_2019, avg(y_2020) as y_2020 from (select A.*, B.incomegroup from urban as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by incomegroup order by avg(y_2000) Desc", conn)
df_u.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_urban_incomewise.csv", index = False)
df_u.head()
# Out:
#            incomegroup     y_2000     y_2001     y_2002     y_2003     y_2004  \
# 0          High income  99.869173  99.863298  99.862280  99.865040  99.861302
# 1  Upper middle income  95.640829  95.586259  95.791040  95.887622  95.921667
# 2  Lower middle income  80.154001  79.870718  80.815119  81.009840  81.913424
# 3           Low income  43.715051  44.502150  45.640630  47.594088  48.255518
#
#       y_2005     y_2006     y_2007     y_2008  ...     y_2011     y_2012  \
# 0  99.865910  99.883209  99.876412  99.889198  ...  99.947572  99.962450
# 1  95.939656  96.106028  96.601357  96.782632  ...  97.222242  97.524064
# 2  82.208544  83.365782  84.811661  84.998483  ...  87.777049  88.058229
# 3  48.624304  50.797021  50.047675  49.025199  ...  55.670253  58.616393
#
#       y_2013     y_2014     y_2015     y_2016     y_2017     y_2018  \
# 0  99.954913  99.971022  99.971934  99.976215  99.985319  99.988866
# 1  97.576988  97.729520  97.845314  97.971789  98.255234  98.338057
# ...

# %%
df_r = pd.read_sql("select incomegroup, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002, avg(y_2003) as y_2003, avg(y_2004) as y_2004,  avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007, avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012, avg(y_2013) as y_2013, avg(y_2014) as y_2014, avg(y_2015) as y_2015, avg(y_2016) as y_2016, avg(y_2017) as y_2017, avg(y_2018) as y_2018, avg(y_2019) as y_2019, avg(y_2020) as y_2020 from (select A.*, B.incomegroup from rural_access as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by incomegroup order by avg(y_2000) Desc", conn)
df_r.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/avg_rural_incomewise.csv", index = False)
df_r.head()
# Out:
#            incomegroup     y_2000     y_2001     y_2002     y_2003     y_2004  \
# 0          High income  98.038194  98.074341  98.272302  98.559078  98.362110
# 1  Upper middle income  80.212925  81.278877  81.713726  82.182314  82.640443
# 2  Lower middle income  41.862179  43.306996  43.137884  45.172739  45.719837
# 3           Low income  14.304663  13.053777  12.033645  10.327263  10.134068
#
#       y_2005     y_2006     y_2007     y_2008  ...     y_2011     y_2012  \
# 0  98.472703  98.820983  98.702453  98.758098  ...  99.372256  99.589491
# 1  83.243447  83.873524  83.680665  84.418125  ...  86.556369  88.808721
# 2  47.096520  48.815147  50.716326  51.456997  ...  57.259936  59.320783
# 3  10.847200  11.649358  11.440409  12.522963  ...  16.327947  17.716923
#
#       y_2013     y_2014     y_2015     y_2016     y_2017     y_2018  \
# 0  99.566395  99.688130  99.734039  99.758130  99.773230  99.815855
# 1  89.311928  89.489296  90.074475  90.427620  92.593538  91.262295
# ...

# %% [markdown]
# ### Q4 A chart to depict the increase in count of country with greater than 75% electricity access in rural areas across different year
# #### total, urban & rural

# %%
df_t = pd.read_sql("select SUBSTRING(years, 3,4) as years, sum(new) as country_count_total from (select years, case when electricity > 75 then 1 else 0 end new from (select A.*, B.region, B.incomegroup, B.specialnotes from Total as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null and B.region is not null) as N unpivot  (electricity for years in (y_1990,y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) m) o group by SUBSTRING(years, 3,4) order by SUBSTRING(years, 3,4)", conn)
df_t.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/country count total.csv", index = False)
df_t.head()
# Out:
#   years  country_count_total
# 0  1990                   93
# 1  1991                   96
# 2  1992                  101
# 3  1993                  102
# 4  1994                  105

# %%
df_u = pd.read_sql("select SUBSTRING(years, 3,4) as years, sum(new) as country_count_urban from (select years, case when electricity > 75 then 1 else 0 end new from (select A.*, B.region, B.incomegroup, B.specialnotes from urban as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null and B.region is not null) as N unpivot  (electricity for years in (y_1990,y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) m) o group by SUBSTRING(years, 3,4) order by SUBSTRING(years, 3,4)", conn)
df_u.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/country count urban.csv", index = False)
df_u.head()
# Out:
#   years  country_count_urban
# 0  1990                   96
# 1  1991                  103
# 2  1992                  112
# 3  1993                  117
# 4  1994                  121

# %%
df_r = pd.read_sql("select SUBSTRING(years, 3,4) as years, sum(new) as country_count_rural from (select years, case when electricity > 75 then 1 else 0 end new from (select A.*, B.region, B.incomegroup, B.specialnotes from rural_access as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null and B.region is not null) as N unpivot  (electricity for years in (y_1990,y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020)) m) o group by SUBSTRING(years, 3,4) order by SUBSTRING(years, 3,4)", conn)
df_r.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/country count rural.csv", index = False)
df_r.head()
# Out:
#   years  country_count_rural
# 0  1990                   84
# 1  1991                   85
# 2  1992                   90
# 3  1993                   90
# 4  1994                   93

# %%
count_of_all = pd.concat([df_t.set_index('years'), df_u.set_index('years'), df_r.set_index('years')], axis = 1)
count_of_all.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/country count all.csv")
count_of_all.head()
# Out:
#        country_count_total  country_count_urban  country_count_rural
# years
# 1990                    93                   96                   84
# 1991                    96                  103                   85
# 1992                   101                  112                   90
# 1993                   102                  117                   90
# 1994                   105                  121                   93

# %% [markdown]
# ### Q5 Define a way/KPI to present the evolution of nuclear power presence grouped by Region and IncomeGroup. How was the nuclear power generation in the region of Europe & Central Asia as compared to Sub-Saharan Africa. income group wise electricity utilization by nuclear energy

# %% [markdown]
# #### income wise electricity utilization by nuclear energy

# %%
df_income = pd.read_sql("select incomegroup,  avg(y_1990) as y_1990,  avg(y_1991) as y_1991,  avg(y_1992) as y_1992,  avg(y_1993) as y_1993,  avg(y_1994) as y_1994, avg(y_1995) as y_1995, avg(y_1996) as y_1996, avg(y_1997) as y_1997, avg(y_1998) as y_1998,  avg(y_1999) as y_1999, avg(y_2000) as y_2000, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002,  avg(y_2003) as y_2003, avg(y_2004) as y_2004, avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007,  avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012,  avg(y_2013) as y_2013, avg(y_2014) as y_2014 from (select A.*, B.region, B.incomegroup, B.specialnotes from nuclear as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by incomegroup order by avg(y_2000) Desc", conn)
df_income.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/income-wise neaclear.csv", index = False)
df_income
# Out:
#            incomegroup     y_1990     y_1991     y_1992     y_1993     y_1994  \
# 0          High income  13.152770  13.148178  13.235442  13.465822  13.282424
# 1  Upper middle income   1.909165   1.820743   1.789766   1.892356   2.000959
# 2  Lower middle income   0.788483   0.823558   0.900452   0.978700   1.010073
# 3           Low income   0.000000   0.000000   0.000000   0.000000   0.000000
#
#       y_1995     y_1996     y_1997     y_1998  ...     y_2005     y_2006  \
# 0  13.273642  13.434789  13.356667  13.250431  ...  13.111507  13.053782
# 1   2.235978   3.145333   2.890946   2.789927  ...   3.029627   3.090472
# 2   1.057235   1.247798   1.281228   1.253531  ...   1.427415   1.390590
# 3   0.000000   0.000000   0.000000   0.000000  ...   0.000000   0.000000
#
#       y_2007     y_2008     y_2009     y_2010     y_2011     y_2012  \
# 0  12.646348  12.822355  12.922340  11.148915  11.169944  10.741514
# 1   2.821018   2.836585   2.924251   2.627371   2.539043   2.409113
# ...

# %% [markdown]
# #### region wise electricity utilization by nuclear energy

# %%
df_region = pd.read_sql("select region,  avg(y_1990) as y_1990,  avg(y_1991) as y_1991,  avg(y_1992) as y_1992,  avg(y_1993) as y_1993,  avg(y_1994) as y_1994, avg(y_1995) as y_1995, avg(y_1996) as y_1996, avg(y_1997) as y_1997, avg(y_1998) as y_1998,  avg(y_1999) as y_1999, avg(y_2000) as y_2000, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002,  avg(y_2003) as y_2003, avg(y_2004) as y_2004, avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007,  avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012,  avg(y_2013) as y_2013, avg(y_2014) as y_2014 from (select A.*, B.region, B.incomegroup, B.specialnotes from nuclear as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by region order by avg(y_2000) Desc", conn)
df_region.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/region-wise neaclear.csv", index = False)
df_region
# Out:
#                        region     y_1990     y_1991     y_1992     y_1993  \
# 0               North America  17.116232  18.327417  17.772406  18.365028
# 1       Europe & Central Asia  13.217253  13.145126  13.393116  13.835615
# 2         East Asia & Pacific   4.585797   4.588363   4.382811   4.256851
# 3                  South Asia   0.575114   0.533575   0.637431   0.495451
# 4   Latin America & Caribbean   0.851859   0.875170   0.778518   0.780760
# 5          Sub-Saharan Africa   0.243271   0.249613   0.242164   0.181953
# 6  Middle East & North Africa   0.000000   0.000000   0.000000   0.000000
#
#       y_1994     y_1995     y_1996     y_1997     y_1998  ...     y_2005  \
# 0  19.537212  18.765940  17.889941  16.266890  15.751409  ...  16.912067
# 1  13.746131  13.917354  14.987578  14.777426  14.453292  ...  14.378081
# 2   4.091456   3.965184   3.968743   3.917840   4.379408  ...   3.938217
# 3   0.479870   0.546413   0.526537   0.547299   0.560142  ...   1.014748
# ...

# %% [markdown]
# #### income group wise electricity utilization by oil

# %%
df_income = pd.read_sql("select incomegroup,  avg(y_1990) as y_1990,  avg(y_1991) as y_1991,  avg(y_1992) as y_1992,  avg(y_1993) as y_1993,  avg(y_1994) as y_1994, avg(y_1995) as y_1995, avg(y_1996) as y_1996, avg(y_1997) as y_1997, avg(y_1998) as y_1998,  avg(y_1999) as y_1999, avg(y_2000) as y_2000, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002,  avg(y_2003) as y_2003, avg(y_2004) as y_2004, avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007,  avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012,  avg(y_2013) as y_2013, avg(y_2014) as y_2014 from (select A.*, B.region, B.incomegroup, B.specialnotes from oil as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by incomegroup order by avg(y_2000) Desc", conn)
df_income.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/income-wise oil.csv", index = False)
df_income
# Out:
#            incomegroup     y_1990     y_1991     y_1992     y_1993     y_1994  \
# 0           Low income  30.242232  26.650987  32.067429  32.187568  35.001829
# 1  Lower middle income  21.204203  23.271980  23.837174  23.405828  22.356909
# 2  Upper middle income  29.932221  28.176257  27.975931  25.623938  25.703837
# 3          High income  16.240513  17.689396  17.175320  15.521220  15.617560
#
#       y_1995     y_1996     y_1997     y_1998  ...     y_2005     y_2006  \
# 0  33.411207  33.889801  35.136324  35.449917  ...  37.436551  36.701141
# 1  24.839267  24.117303  26.015711  25.298335  ...  23.340917  23.780340
# 2  25.881479  24.824837  24.744329  25.119659  ...  15.747180  14.519317
# 3  16.009953  15.471070  15.470232  16.212842  ...  12.595981  12.624661
#
#       y_2007     y_2008     y_2009     y_2010     y_2011     y_2012  \
# 0  37.974514  36.155113  33.125122  28.077443  25.692064  32.557603
# 1  24.718093  24.478540  25.223562  23.359049  24.515912  23.707735
# ...

# %% [markdown]
# #### region wise electricity utilization by oil

# %%
df_region = pd.read_sql("select region,  avg(y_1990) as y_1990,  avg(y_1991) as y_1991,  avg(y_1992) as y_1992,  avg(y_1993) as y_1993,  avg(y_1994) as y_1994, avg(y_1995) as y_1995, avg(y_1996) as y_1996, avg(y_1997) as y_1997, avg(y_1998) as y_1998,  avg(y_1999) as y_1999, avg(y_2000) as y_2000, avg(y_2000) as y_2000, avg(y_2001) as y_2001, avg(y_2002) as y_2002,  avg(y_2003) as y_2003, avg(y_2004) as y_2004, avg(y_2005) as y_2005, avg(y_2006) as y_2006, avg(y_2007) as y_2007,  avg(y_2008) as y_2008, avg(y_2009) as y_2009, avg(y_2010) as y_2010, avg(y_2011) as y_2011, avg(y_2012) as y_2012,  avg(y_2013) as y_2013, avg(y_2014) as y_2014 from (select A.*, B.region, B.incomegroup, B.specialnotes from oil as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null) as N where incomegroup is not null group by region order by avg(y_2000) Desc", conn)
df_region.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/region-wise oil.csv", index = False)
df_region
# Out:
#                        region     y_1990     y_1991     y_1992     y_1993  \
# 0  Middle East & North Africa  44.842441  49.175191  46.886500  44.911604
# 1   Latin America & Caribbean  23.566203  24.929002  27.795759  25.242195
# 2          Sub-Saharan Africa  22.208370  20.051896  23.014884  23.127240
# 3                  South Asia   5.938672   7.905291  11.553334  10.336199
# 4         East Asia & Pacific  22.050069  22.316528  21.321519  19.577419
# 5       Europe & Central Asia  15.376982  15.001591  14.183371  12.872990
# 6               North America   3.747751   3.342103   3.126900   2.998561
#
#       y_1994     y_1995     y_1996     y_1997     y_1998  ...     y_2005  \
# 0  44.592434  43.184356  42.229101  42.663558  43.317826  ...  34.758825
# 1  26.932692  30.541545  29.239626  31.341275  33.634398  ...  28.855344
# 2  24.145572  22.944939  22.495470  23.789789  22.790491  ...  24.305883
# 3  10.991894  10.738721  15.776204  18.844827  17.742449  ...  18.574299
# ...

# %% [markdown]
# #
# ## Q6 A chart to present the production of electricity across different sources (nuclear, oil, etc.) as a function of time

# %%
df_world = pd.read_sql("select y_country_name, y_indicator_name ,y_1971, y_1972, y_1973, y_1974, y_1975, y_1976, y_1977, y_1978, y_1979, y_1980,y_1981, y_1982, y_1983, y_1984, y_1985, y_1986, y_1987, y_1988, y_1989, y_1990,y_1991, y_1992, y_1993, y_1994, y_1995, y_1996, y_1997, y_1998, y_1999, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015 from (select * from nuclear  union select * from oil union select *, 8.25 as y_2015  from power_loss) as N", conn)
df_world.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/different sources.csv", index = False)
df_world
# Out:
#                   y_country_name  \
# 0                    Afghanistan
# 1                    Afghanistan
# 2                    Afghanistan
# 3    Africa Eastern and Southern
# 4    Africa Eastern and Southern
# ..                           ...
# 793                       Zambia
# 794                       Zambia
# 795                     Zimbabwe
# 796                     Zimbabwe
# 797                     Zimbabwe
#
#                                       y_indicator_name    y_1971    y_1972  \
# 0    Electric power transmission and distribution l...       NaN       NaN
# 1    Electricity production from nuclear sources (%...       NaN       NaN
# 2    Electricity production from oil sources (% of ...       NaN       NaN
# 3    Electric power transmission and distribution l...  7.854249  7.114661
# 4    Electricity production from nuclear sources (%...  0.000000  0.000000
# ..                                                 ...       ...       ...
# ...

# %% [markdown]
# ### --Average percent of population utlize electricity (groups of countries)

# %%
df_group = pd.read_sql("select A.y_Country_Name, y_2000, y_2001, y_2002, y_2003, y_2004, y_2005, y_2006, y_2007, y_2008, y_2009, y_2010, y_2011, y_2012, y_2013, y_2014, y_2015, y_2016, y_2017, y_2018, y_2019, y_2020, B.specialnotes from Total as A full outer join metadata_country as B on A.y_country_code = B.country_code where B.tablename is not Null and region is null", conn)
df_group.to_csv("C:/Users/batman/Desktop/my territory/Projects/complete data analysis/Filetred data/group average.csv", index = False)
df_group.head()
# Out:
#                    y_Country_Name      y_2000      y_2001      y_2002  \
# 0     Africa Eastern and Southern   19.811283   19.900570   21.525812
# 1      Africa Western and Central   34.150688   35.266460   35.761967
# 2                      Arab World   80.736145   81.586235   81.540222
# 3  Central Europe and the Baltics  100.000000  100.000000  100.000000
# 4          Caribbean small states   86.829292   89.453590   89.286476
#
#        y_2003      y_2004      y_2005      y_2006      y_2007      y_2008  \
# 0   22.474310   23.781918   23.487415   24.763538   26.766518   25.934179
# 1   39.876236   37.545959   37.847034   39.836559   40.788780   41.744659
# 2   82.508156   82.503685   83.212982   85.459000   83.764442   83.386993
# 3  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 4   89.376366   89.860268   90.284721   90.760651   91.711372   92.880829
#
#    ...      y_2012      y_2013      y_2014      y_2015     y_2016      y_2017  \
# ...
